# %%
import pandas as pd

path = "/Users/lindseylewis/Downloads/SchoolGrades25.xlsx"

raw = pd.read_excel(path, header=None, skiprows=2)

header_row_idx = raw.index[raw.iloc[:, 0].astype(str).str.strip().eq("District Number")][0]

raw.columns = raw.iloc[header_row_idx].astype(str).str.strip()

df = raw.iloc[header_row_idx + 1 :].copy()

df = df.dropna(axis=1, how="all")

df = df[df["District Number"].astype(str).str.strip() != "District Number"]

print(df.head())
print(df.columns.to_list()[:25])
print(df.shape)
# Out:
# 1 District Number District Name School Number Virtual Provider Number  \
# 2              01       ALACHUA          0031                     NaN
# 3              01       ALACHUA          0041                     NaN
# 4              01       ALACHUA          0071                     NaN
# 5              01       ALACHUA          0091                     NaN
# 6              01       ALACHUA          0101                     NaN
#
# 1                         School Name  \
# 2  CAROLYN BEATRICE PARKER ELEMENTARY
# 3    STEPHEN FOSTER ELEMENTARY SCHOOL
# 4       LAKE FOREST ELEMENTARY SCHOOL
# 5        LITTLEWOOD ELEMENTARY SCHOOL
# 6    W. A. METCALFE ELEMENTARY SCHOOL
#
# 1 Grade 3 English Language Arts Achievement English Language Arts Achievement  \
# 2                                        51                                58
# 3                                        36                                44
# 4                                        43                                40
# 5                                        71                                66
# 6                                        26                                30
#
# 1 English Language Arts Learning Gains  \
# 2                                   60
# 3                                   52
# 4                                   47
# 5                                   59
# 6                                   52
#
# 1 English Language Arts Learning Gains of the Lowest 25%  \
# 2                                                 51
# 3                                                 41
# 4                                                 61
# 5                                                 48
# 6                                                 60
#
# 1 Mathematics Achievement  ... Grade 2001 Grade 2000 Grade 1999  \
# 2                      53  ...          A          A          B
# 3                      41  ...          C          A          C
# 4                      29  ...          C          C          D
# 5                      70  ...          B          B          B
# 6                      35  ...          D          C          D
#
# 1 Was the collocated rule used? Collocated Number Charter School Title I  \
# 2                             N               NaN             NO     YES
# 3                             N               NaN             NO     YES
# 4                             N               NaN             NO     YES
# 5                             N               NaN             NO     YES
# 6                             N               NaN             NO     YES
#
# 1 Alternative/ESE Center School School Type  \
# 2                             N          01
# 3                             N          01
# 4                             N          01
# 5                             N          01
# 6                             N          01
#
# 1 Percent of Economically Disadvantaged Students
# 2                                           66.1
# 3                                            100
# 4                                            100
# 5                                             75
# 6                                            100
#
# [5 rows x 54 columns]
# ['District Number', 'District Name', 'School Number', 'Virtual Provider Number', 'School Name', 'Grade 3 English Language Arts Achievement', 'English Language Arts Achievement', 'English Language Arts Learning Gains', 'English Language Arts Learning Gains of the Lowest 25%', 'Mathematics Achievement', 'Mathematics Learning Gains', 'Mathematics Learning Gains of the Lowest 25%', 'Science Achievement', 'Social Studies Achievement', 'Middle School Acceleration', 'Graduation Rate 2023-24', 'College and Career Acceleration 2023-24', 'Total Points Earned', 'Total Components', 'Percent of Total Possible Points', 'Percent Tested', 'Grade 2025', 'Grade 2024', 'Informational Baseline Grade 2023', 'Grade 2022']
# (3465, 54)

# %%
for col in df.columns:
    df[col] = df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

out_path = "/Users/lindseylewis/Desktop/ML/accountability-dbt-pipeline/florida-accountability-dbt/accountability_project/seeds/fl_school_grades_2025.csv"

df.to_csv(out_path, index=False)
print("Wrote:", out_path)

df.shape
df.head()
# Out:
# Wrote: /Users/lindseylewis/Desktop/ML/accountability-dbt-pipeline/florida-accountability-dbt/accountability_project/seeds/fl_school_grades_2025.csv
# 1 District Number District Name School Number Virtual Provider Number  \
# 2              01       ALACHUA          0031                     NaN
# 3              01       ALACHUA          0041                     NaN
# 4              01       ALACHUA          0071                     NaN
# 5              01       ALACHUA          0091                     NaN
# 6              01       ALACHUA          0101                     NaN
#
# 1                         School Name  \
# 2  CAROLYN BEATRICE PARKER ELEMENTARY
# 3    STEPHEN FOSTER ELEMENTARY SCHOOL
# 4       LAKE FOREST ELEMENTARY SCHOOL
# 5        LITTLEWOOD ELEMENTARY SCHOOL
# 6    W. A. METCALFE ELEMENTARY SCHOOL
#
# 1  Grade 3 English Language Arts Achievement  \
# 2                                       51.0
# 3                                       36.0
# 4                                       43.0
# 5                                       71.0
# 6                                       26.0
#
# 1  English Language Arts Achievement  English Language Arts Learning Gains  \
# 2                               58.0                                  60.0
# 3                               44.0                                  52.0
# 4                               40.0                                  47.0
# 5                               66.0                                  59.0
# 6                               30.0                                  52.0
#
# 1  English Language Arts Learning Gains of the Lowest 25%  \
# 2                                               51.0
# 3                                               41.0
# 4                                               61.0
# 5                                               48.0
# 6                                               60.0
#
# 1  Mathematics Achievement  ...  Grade 2001  Grade 2000  Grade 1999  \
# 2                     53.0  ...           A           A           B
# 3                     41.0  ...           C           A           C
# 4                     29.0  ...           C           C           D
# 5                     70.0  ...           B           B           B
# 6                     35.0  ...           D           C           D
#
# 1  Was the collocated rule used?  Collocated Number  Charter School  Title I  \
# 2                              N                NaN              NO      YES
# 3                              N                NaN              NO      YES
# 4                              N                NaN              NO      YES
# 5                              N                NaN              NO      YES
# 6                              N                NaN              NO      YES
#
# 1  Alternative/ESE Center School  School Type  \
# 2                              N           01
# 3                              N           01
# 4                              N           01
# 5                              N           01
# 6                              N           01
#
# 1  Percent of Economically Disadvantaged Students
# 2                                            66.1
# 3                                           100.0
# 4                                           100.0
# 5                                            75.0
# 6                                           100.0
#
# [5 rows x 54 columns]
